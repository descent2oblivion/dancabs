// %%
%use lets-plot
// Out:
//    <div id="hSD56a"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.4.2.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
// ...

// %%
var datos = mapOf<String, Any>(
    "Meses" to listOf("junio '18", "julio '18", "agosto '18",
                      "septiembre '18", "octubre '18", "noviembre '18",
                      "diciembre '18", 
                      
                      //enero 2019
                      "enero '19", "febrero '19", "marzo '19", 
                      "abril '19", "mayo '19", "junio '19", 
                      "julio '19",  "agosto '19","septiembre '19", 
                      "octubre '19", "noviembre '19", "diciembre '19",
                      
                      //enero 2020
                      "enero '20", "febrero '20", "marzo '20", 
                      "abril '20", "mayo '20", "junio '20", 
                      
                      //este mes
                      "julio '20"),
    
    "Valor" to listOf(
                     1062, 718, 861,
                     2724, 3472, 1761,
                     1501,
                      
                     //"enero 2019"
                     3207, 2886, 1834,
                     1846, 3168, 2145,
                     672,  2805, 3599,
                     5007, 2053, 3791,
        
                     //"enero 2020"
                     2629, 2053, 3308,
                     5652, 6102, 8249,
                      
                     //"Este mes"
                     4307)
)

var z = lets_plot(datos)

var layer = geom_line(stat = Stat.identity){
    x = "Meses"
    y = "Valor"
}

(z + layer)
// Out:
//    <div id="Ak2sXI"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'mapping':{
// },
// 'data':{
// 'Meses':["junio '18","julio '18","agosto '18","septiembre '18","octubre '18","noviembre '18","diciembre '18","enero '19","febrero '19","marzo '19","abril '19","mayo '19","junio '19","julio '19","agosto '19","septiembre '19","octubre '19","noviembre '19","diciembre '19","enero '20","febrero '20","marzo '20","abril '20","mayo '20","junio '20","julio '20"],
// 'Valor':[1062.0,718.0,861.0,2724.0,3472.0,1761.0,1501.0,3207.0,2886.0,1834.0,1846.0,3168.0,2145.0,672.0,2805.0,3599.0,5007.0,2053.0,3791.0,2629.0,2053.0,3308.0,5652.0,6102.0,8249.0,4307.0]
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"identity",
// 'mapping':{
// 'x':"Meses",
// 'y':"Valor"
// },
// 'data':{
// },
// 'position':"identity",
// 'geom':"line"
// }]
// };
// ...

// %%
var datos = mapOf<String, Any>(
    "Meses" to listOf("junio '18", "julio '18", "agosto '18",
                      "septiembre '18", "octubre '18", "noviembre '18",
                      "diciembre '18"),
    
    "Valor" to listOf(
                     1062, 718, 861,
                     2724, 3472, 1761,
                     1501)
)

var z = lets_plot(datos)

var layer = geom_line(stat = Stat.identity){
    x = "Meses"
    y = "Valor"
}

(z + layer)
// Out:
//    <div id="v6HXtu"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'mapping':{
// },
// 'data':{
// 'Meses':["junio '18","julio '18","agosto '18","septiembre '18","octubre '18","noviembre '18","diciembre '18"],
// 'Valor':[1062.0,718.0,861.0,2724.0,3472.0,1761.0,1501.0]
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"identity",
// 'mapping':{
// 'x':"Meses",
// 'y':"Valor"
// },
// 'data':{
// },
// 'position':"identity",
// 'geom':"line"
// }]
// };
//            var plotContainer = document.getElementById("v6HXtu");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
var datos = mapOf<String, Any>(
    "Meses" to listOf(
                      //enero 2019
                      "enero '19", "febrero '19", "marzo '19", 
                      "abril '19", "mayo '19", "junio '19", 
                      "julio '19",  "agosto '19","septiembre '19", 
                      "octubre '19", "noviembre '19", "diciembre '19"),
    
    "Valor" to listOf(//"enero 2019"
                     3207, 2886, 1834,
                     1846, 3168, 2145,
                     672,  2805, 3599,
                     5007, 2053, 3791)
)

var z = lets_plot(datos)

var layer = geom_line(stat = Stat.identity){
    x = "Meses"
    y = "Valor"
}

(z + layer)
// Out:
//    <div id="txfjsi"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'mapping':{
// },
// 'data':{
// 'Meses':["enero '19","febrero '19","marzo '19","abril '19","mayo '19","junio '19","julio '19","agosto '19","septiembre '19","octubre '19","noviembre '19","diciembre '19"],
// 'Valor':[3207.0,2886.0,1834.0,1846.0,3168.0,2145.0,672.0,2805.0,3599.0,5007.0,2053.0,3791.0]
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"identity",
// 'mapping':{
// 'x':"Meses",
// 'y':"Valor"
// },
// 'data':{
// },
// 'position':"identity",
// 'geom':"line"
// }]
// };
//            var plotContainer = document.getElementById("txfjsi");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
var datos = mapOf<String, Any>(
    "Meses" to listOf(
                      //enero 2020
                      "enero '20", "febrero '20", "marzo '20", 
                      "abril '20", "mayo '20", "junio '20",
        
                      //este mes
                      "julio '20"),
    
    "Valor" to listOf(
                     //"enero 2020"
                     2629, 2053, 3308,
                     5652, 6102, 8249,
                      
                     //"Este mes"
                     4307)
)

var z = lets_plot(datos)

var layer = geom_line(stat = Stat.identity){
    x = "Meses"
    y = "Valor"
}

(z + layer)
// Out:
//    <div id="XX9Kc3"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'mapping':{
// },
// 'data':{
// 'Meses':["enero '20","febrero '20","marzo '20","abril '20","mayo '20","junio '20","julio '20"],
// 'Valor':[2629.0,2053.0,3308.0,5652.0,6102.0,8249.0,4307.0]
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"identity",
// 'mapping':{
// 'x':"Meses",
// 'y':"Valor"
// },
// 'data':{
// },
// 'position':"identity",
// 'geom':"line"
// }]
// };
//            var plotContainer = document.getElementById("XX9Kc3");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
var ingreso  = 20232

var impuesto = (ingreso / 100) * 5

var ingreso_p = ingreso - ((ingreso / 100) * 5)

var envios = 1016

var prima = 3713

var daniel = ingreso_p - envios - prima

var datos = mapOf<String, Any>(
    "Cantidad" to listOf(ingreso, impuesto, ingreso_p, envios, prima, daniel),
    "Conceptos" to listOf("Ingresos","Impuesto", "post-Paypal","Envios","Prima","Daniel")
)

var z = lets_plot(datos)

var layer = geom_bar(stat = Stat.identity){
    x = "Conceptos"
    y = "Cantidad"
    fill = "Conceptos"
}

println("Ingreso: $ingreso \nImpuesto Paypal: $impuesto \nIngreso despues de Paypal: $ingreso_p \nEnvios: $envios \nPrima: $prima \nDaniel: $daniel")

(z + layer)
// Out:
// Ingreso: 20232
// Impuesto Paypal: 1010
// Ingreso despues de Paypal: 19222
// Envios: 1016
// Prima: 3713
// Daniel: 14493
//    <div id="k3WqIX"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'mapping':{
// },
// 'data':{
// 'Conceptos':["Ingresos","Impuesto","post-Paypal","Envios","Prima","Daniel"],
// 'Cantidad':[20232.0,1010.0,19222.0,1016.0,3713.0,14493.0]
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"identity",
// 'mapping':{
// 'x':"Conceptos",
// 'y':"Cantidad",
// 'fill':"Conceptos"
// },
// 'data':{
// },
// 'position':"stack",
// 'geom':"bar"
// }]
// };
//            var plotContainer = document.getElementById("k3WqIX");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [raw]
// parte de la prima -> 10%
//
// sueldo de la prima semanal -> 1200 MXN -> 58.5 USD (20.5 MXN)

// %%
var iP = 3713 //Ingreso de la prima

var pDP = iP / 10 //parte de la prima

var sDP = 58.5 //sueldo de la prima

var p14 = sDP * 14 //14 semanas de la prima 

var cP = pDP + p14 //costo de la prima

var gan = iP - cP //Ganancias

var datos = mapOf<String, Any>(
    "Cantidad" to listOf(iP, pDP, p14, cP, gan),
    "Conceptos" to listOf("Ingreso", "Su parte", 
                          "14 semanas", "Costo", "Genera")
)

var z = lets_plot(datos)

var layer = geom_bar(stat = Stat.identity){
    x = "Conceptos"
    y = "Cantidad"
    fill = "Conceptos"
}

println("Ingresos: $iP \nSu parte: $pDP \n14 semanas: $p14 \nCosto: $cP \nGenera: $gan")

(z + layer + ggtitle("Prima"))
// Out:
// Ingresos: 3713
// Su parte: 371
// 14 semanas: 819.0
// Costo: 1190.0
// Genera: 2523.0
//    <div id="WgzTYS"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'ggtitle':{
// 'text':"Prima"
// },
// 'mapping':{
// },
// 'data':{
// 'Conceptos':["Ingreso","Su parte","14 semanas","Costo","Genera"],
// 'Cantidad':[3713.0,371.0,819.0,1190.0,2523.0]
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"identity",
// 'mapping':{
// 'x':"Conceptos",
// 'y':"Cantidad",
// 'fill':"Conceptos"
// },
// 'data':{
// },
// 'position':"stack",
// 'geom':"bar"
// }]
// };
//            var plotContainer = document.getElementById("WgzTYS");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
